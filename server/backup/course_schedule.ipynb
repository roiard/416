# %% [markdown]
# # Import pandas

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from random import randint

# %% [markdown]
# # First, randomly distribute the courses

# %%
df = pd.read_excel('./course_2023.xlsx', sheet_name=2)

df.head()
# Out:
#    Class Nbr Subj    CRS                          Course Title   SBC  Cmp  \
# 0      92229  CSE  101.0           Computer Science Principles  TECH  LEC
# 1      92230  NaN    NaN                                   NaN   NaN  LAB
# 2      92231  CSE  114.0  Intro to Object-Oriented Programming  TECH  LEC
# 3      92232  NaN    NaN                                   NaN   NaN  LAB
# 4      92233  CSE  214.0                       Data Structures   NaN  LEC
#
#   Sctn Credits  Days Start Time  End Time  Room       Instructor
# 0   90       3  TUTH   10:30 AM  11:50 AM  C105  Francois Rameau
# 1  L90     NaN  LABM   12:30 PM   1:50 PM  C105              NaN
# 2   90       4    MW    2:00 PM   3:20 PM  C105   Antonino Mione
# 3  L90     NaN  TUTH    2:00 PM   3:20 PM  C105              NaN
# 4   90       4  TUTH   10:30 AM  11:50 AM  B103    Byungkon Kang

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32264\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.head()
# Out:
#    Class Nbr Subj    CRS                          Course Title   SBC  Cmp  \
# 0      92229  CSE  101.0           Computer Science Principles  TECH  LEC
# 1      92230  CSE  101.0           Computer Science Principles  TECH  LAB
# 2      92231  CSE  114.0  Intro to Object-Oriented Programming  TECH  LEC
# 3      92232  CSE  114.0  Intro to Object-Oriented Programming  TECH  LAB
# 4      92233  CSE  214.0                       Data Structures  TECH  LEC
#
#   Sctn Credits  Days Start Time  End Time  Room       Instructor
# 0   90       3  TUTH   10:30 AM  11:50 AM  C105  Francois Rameau
# 1  L90       3  LABM   12:30 PM   1:50 PM  C105  Francois Rameau
# 2   90       4    MW    2:00 PM   3:20 PM  C105   Antonino Mione
# 3  L90       4  TUTH    2:00 PM   3:20 PM  C105   Antonino Mione
# 4   90       4  TUTH   10:30 AM  11:50 AM  B103    Byungkon Kang

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Class Nbr     40 non-null     int64
#  1   Subj          40 non-null     object
#  2   CRS           40 non-null     float64
#  3   Course Title  40 non-null     object
#  4   SBC           40 non-null     object
#  5   Cmp           40 non-null     object
#  6   Sctn          40 non-null     object
#  7   Credits       40 non-null     object
#  8   Days          40 non-null     object
#  9   Start Time    40 non-null     object
#  10  End Time      40 non-null     object
#  11  Room          40 non-null     object
#  12  Instructor    40 non-null     object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 4.2+ KB

# %%
df['Total time'] = ((pd.to_datetime(df['End Time']) - pd.to_datetime(df['Start Time']))).dt.total_seconds() / 60
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32264\2471917587.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Total time'] = ((pd.to_datetime(df['End Time']) - pd.to_datetime(df['Start Time']))).dt.total_seconds() / 60
# C:\Users\USER\AppData\Local\Temp\ipykernel_32264\2471917587.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Total time'] = ((pd.to_datetime(df['End Time']) - pd.to_datetime(df['Start Time']))).dt.total_seconds() / 60

# %%
df['Start Time'], df['End Time'] = None, None

df_filtered = df[df['Total time'] >0]

# %%
start_time = {
    0: '9:00 AM',
    1:'10:30 AM', 
    2: '12:30 PM',
    3: '2:00 PM',
    4: '3:30 PM',
    5: '5:00 PM'
    }

num = df_filtered.shape[0] // 6
extra = df_filtered.shape[0] % 6

lst = [num for _ in range(6)]

for _ in range(extra):
    idx = randint(0, num-1)
    lst[idx] += 1

time_slots = []

for i in range(6):
    time_slots += [start_time[i]] * lst[i]
             
np.random.shuffle(time_slots)         
df_filtered['Start Time'] = time_slots
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32264\4028327517.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Start Time'] = time_slots

# %%
def calculate_end_time(row):

    start_time_dt = datetime.strptime(row['Start Time'], '%I:%M %p')
    end_time_dt = start_time_dt + timedelta(minutes=row['Total time'])
    end_time_str = end_time_dt.strftime('%I:%M %p')

    return end_time_str

df_filtered['End Time'] = df_filtered.apply(calculate_end_time, axis=1)

df_filtered
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_32264\1497594676.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['End Time'] = df_filtered.apply(calculate_end_time, axis=1)
#     Class Nbr Subj    CRS                          Course Title  \
# 0       92229  CSE  101.0           Computer Science Principles
# 1       92230  CSE  101.0           Computer Science Principles
# 2       92231  CSE  114.0  Intro to Object-Oriented Programming
# 3       92232  CSE  114.0  Intro to Object-Oriented Programming
# 4       92233  CSE  214.0                       Data Structures
# 5       92234  CSE  214.0                       Data Structures
# 6       92235  CSE  215.0           Foundations of Comp Science
# 7       92236  CSE  215.0           Foundations of Comp Science
# 8       92339  CSE  216.0              Programming Abstractions
# 9       92340  CSE  216.0              Programming Abstractions
# 10      92237  CSE  220.0                Systems Fundamentals I
# 11      92238  CSE  220.0                Systems Fundamentals I
# 12      92291  CSE  300.0              Technical Communications
# 13      92322  CSE  303.0    Intro to the Theory of Computation
# 14      96938  CSE  304.0                       Compiler Design
# 15      92268  CSE  310.0                     Computer Networks
# 16      92342  CSE  316.0  Fundamentals of Software Development
# 17      92321  CSE  320.0               Systems Fundamentals II
# 18      92281  CSE  352.0               Artificial Intelligence
# 19      96966  CSE  354.0           Natural Language Processing
# 20      92239  CSE  373.0                Analysis of Algorithms
# 21      92341  CSE  416.0                  Software Engineering
# 25      92386  CSE  534.0        Fundament of Computer Networks
# 26      92471  CSE  537.0               Artificial Intelligence
# 27      96969  CSE  538.0           Natural Language Processing
# 28      96970  CSE  541.0             Logic in Computer Science
# 31      97249  CSE  600.0   Research in Modern Computer Science
# 32      92292  CSE  644.0                  Seminar in Databases
# 33      92368  CSE  646.0    Seminar in Artificial Intelligence
# 34      96943  CSE  656.0            Seminar in Computer Vision
# 35      92240  CSE  658.0    Seminar on Mobile and Wireless Net
#
#                                             SBC  Cmp Sctn Credits   Days  \
# 0                                          TECH  LEC   90       3   TUTH
# 1                                          TECH  LAB  L90       3   LABM
# 2                                          TECH  LEC   90       4     MW
# 3                                          TECH  LAB  L90       4   TUTH
# 4                                          TECH  LEC   90       4   TUTH
# 5                                          TECH  REC  R90       4   RECW
# 6                                          TECH  LEC   90       4   TUTH
# 7                                          TECH  REC  R90       4  RECTU
# 8                                          TECH  LEC   90       4   TUTH
# 9                                          TECH  REC  R90       4  RECTH
# 10                                         TECH  LEC   90       4     MW
# 11                                         TECH  REC  R90       4   RECM
# 12                                    SPK; WRTD  LEC   90       3     MW
# 13                                    SPK; WRTD  LEC   90       3   TUTH
# 14                                    SPK; WRTD  LEC   90       3   TUTH
# 15                                    SPK; WRTD  LEC   90       3   TUTH
# 16  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3     MW
# 17  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 18  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 19  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 20  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 21  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 25  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 26  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3     MW
# 27  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3   TUTH
# 28  Partially fulfills:\nESI, EXP+, SBS+, STEM+  LEC   90       3     MW
# 31  Partially fulfills:\nESI, EXP+, SBS+, STEM+  SEM  S91  0 to 1      F
# 32  Partially fulfills:\nESI, EXP+, SBS+, STEM+  SEM  S90       1     TU
# 33  Partially fulfills:\nESI, EXP+, SBS+, STEM+  SEM  S90       1     TU
# 34  Partially fulfills:\nESI, EXP+, SBS+, STEM+  SEM  S90       1     TU
# 35  Partially fulfills:\nESI, EXP+, SBS+, STEM+  SEM  S90       1     TU
#
#    Start Time  End Time  Room                Instructor  Total time
# 0     3:30 PM  04:50 PM  C105           Francois Rameau        80.0
# 1     9:00 AM  10:20 AM  C105           Francois Rameau        80.0
# 2     9:00 AM  10:20 AM  C105            Antonino Mione        80.0
# 3     5:00 PM  06:20 PM  C105            Antonino Mione        80.0
# 4    12:30 PM  01:50 PM  B103             Byungkon Kang        80.0
# 5     5:00 PM  05:55 PM  B103             Byungkon Kang        55.0
# 6     5:00 PM  06:20 PM  B207                Zhoulai Fu        80.0
# 7    10:30 AM  11:25 AM  B207                Zhoulai Fu        55.0
# 8     2:00 PM  03:20 PM  B203                Zhoulai Fu        80.0
# 9     9:00 AM  09:55 AM  B203                Zhoulai Fu        55.0
# 10    2:00 PM  03:20 PM  B203               Amos Omondi        80.0
# 11    5:00 PM  05:55 PM  B203               Amos Omondi        55.0
# 12    2:00 PM  03:20 PM  B205      Christopher Houghton        80.0
# 13    2:00 PM  03:20 PM  B204               Amos Omondi        80.0
# 14   10:30 AM  11:50 AM  B103               Amos Omondi        80.0
# 15    3:30 PM  04:50 PM  B204     Aruna Balasubramanian        80.0
# 16    2:00 PM  03:20 PM  B207            Antonino Mione        80.0
# 17    3:30 PM  04:50 PM  B205            Yoon-Seok Yang        80.0
# 18   12:30 PM  01:50 PM  A312             Byungkon Kang        80.0
# 19    5:00 PM  06:20 PM  B313  Niranjan Balasubramanian        80.0
# 20   10:30 AM  11:50 AM  B205               Jihoon Ryoo        80.0
# 21   12:30 PM  01:50 PM  A116               Jihoon Ryoo        80.0
# 25    3:30 PM  04:50 PM  B313     Aruna Balasubramanian        80.0
# 26    3:30 PM  04:50 PM  B314            Seung Soo Park        80.0
# 27    3:30 PM  04:50 PM  B313  Niranjan Balasubramanian        80.0
# 28   10:30 AM  11:50 AM  B313            Seung Soo Park        80.0
# 31    9:00 AM  10:00 AM  A312               Amos Omondi        60.0
# 32   12:30 PM  01:50 PM  B203                Arthur Lee        80.0
# 33   10:30 AM  11:50 AM  B204             Byungkon Kang        80.0
# 34   12:30 PM  01:50 PM  B205           Francois Rameau        80.0
# 35    9:00 AM  10:20 AM  B206               Jihoon Ryoo        80.0
